# %%
from alpha_vantage.sectorperformance import SectorPerformances
import matplotlib.pyplot as plt

sp = SectorPerformances(key='BCA4MC4LW6VN8TVX', output_format='pandas')
data, meta_data = sp.get_sector()
data['Rank A: Real-Time Performance'].plot(kind='bar')
plt.title('Real Time Performance (%) per Sector')
plt.tight_layout()
plt.grid()
plt.show()

# %%
data
# Out:
#                         Rank A: Real-Time Performance  \
# Energy                                         0.0195
# Financials                                     0.0193
# Materials                                      0.0129
# Industrials                                    0.0080
# Consumer Discretionary                         0.0075
# Information Technology                         0.0073
# Health Care                                    0.0071
# Consumer Staples                              -0.0006
# Communication Services                        -0.0024
# Utilities                                     -0.0065
# Real Estate                                   -0.0154
#
#                         Rank B: Day Performance  Rank C: Day Performance  \
# Energy                                  -0.0016                   0.0124
# Financials                              -0.0021                   0.0121
# Materials                                0.0071                   0.0168
# ...

# %%
data['Rank E: Month Performance'].plot(kind='bar')
plt.title('3 Month Performance (%) per Sector')
plt.tight_layout()
plt.grid()
plt.show()

# %%
data['Rank H: Year Performance'].plot(kind='bar')
plt.title('3 Year Performance (%) per Sector')
plt.tight_layout()
plt.grid()
plt.show()

# %%
data['Rank G: Year Performance'].plot(kind='bar')
plt.title('1 Year Performance (%) per Sector')
plt.tight_layout()
plt.grid()
plt.show()

# %%
export_csv = data.to_csv (r'E:\NEU_Courses\Info7370\finalProjects\data\sector_performance.csv', index = ['Energy','Financials','Materials','Industrials','Consumer Discretionary','Information Technology','Health Care','Consumer Staples','Communication Services','Utilities','Real Estate'], header=True)
